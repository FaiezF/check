# %%
a=[('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]
print(sorted(a,key=lamda x:float(x[1]),reverse=True))
# Out:
#   File "<ipython-input-4-10ff251e91d0>", line 2
#     print(sorted(a,key=lamda x:float(x[1]),reverse=True))
#                              ^
# SyntaxError: invalid syntax
